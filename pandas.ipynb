# %%
import pandas as pd

# %%
df = pd.read_csv('/home/vamsi/neural_networks(udemy)/Files/Customer.csv')

# %%
df.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        Henderson        Kentucky        42420  South
# 1      Los Angeles      California        90036   West
# 2  Fort Lauderdale         Florida        33311  South
# 3      Los Angeles      California        90032   West
# 4          Concord  North Carolina        28027  South

# %%
df2 = pd.read_csv('/home/vamsi/neural_networks(udemy)/Files/Customer.csv',index_col=0)
df2.head()
# Out:
#                Customer Name    Segment  Age        Country             City  \
# Customer ID
# CG-12520         Claire Gute   Consumer   67  United States        Henderson
# DV-13045     Darrin Van Huff  Corporate   31  United States      Los Angeles
# SO-20335      Sean O'Donnell   Consumer   65  United States  Fort Lauderdale
# BH-11710     Brosina Hoffman   Consumer   20  United States      Los Angeles
# AA-10480        Andrew Allen   Consumer   50  United States          Concord
#
#                       State  Postal Code Region
# Customer ID
# CG-12520           Kentucky        42420  South
# DV-13045         California        90036   West
# SO-20335            Florida        33311  South
# BH-11710         California        90032   West
# AA-10480     North Carolina        28027  South

# %%
df3 = pd.read_csv('/home/vamsi/neural_networks(udemy)/Files/Customer.csv',index_col=5)
df3.head()
# Out:
#                 Customer ID    Customer Name    Segment  Age        Country  \
# City
# Henderson          CG-12520      Claire Gute   Consumer   67  United States
# Los Angeles        DV-13045  Darrin Van Huff  Corporate   31  United States
# Fort Lauderdale    SO-20335   Sean O'Donnell   Consumer   65  United States
# Los Angeles        BH-11710  Brosina Hoffman   Consumer   20  United States
# Concord            AA-10480     Andrew Allen   Consumer   50  United States
#
#                           State  Postal Code Region
# City
# Henderson              Kentucky        42420  South
# Los Angeles          California        90036   West
# Fort Lauderdale         Florida        33311  South
# Los Angeles          California        90032   West
# Concord          North Carolina        28027  South

# %%
df.describe()
# Out:
#               Age   Postal Code
# count  793.000000    793.000000
# mean    44.467844  55229.717528
# std     15.526673  31679.223816
# min     18.000000   1841.000000
# 25%     31.000000  27217.000000
# 50%     45.000000  55901.000000
# 75%     58.000000  90004.000000
# max     70.000000  99207.000000

# %%
df.iloc[0]
# Out:
# Customer ID           CG-12520
# Customer Name      Claire Gute
# Segment               Consumer
# Age                         67
# Country          United States
# City                 Henderson
# State                 Kentucky
# Postal Code              42420
# Region                   South
# Name: 0, dtype: object

# %%
df2.loc["CG-12520"]
# Out:
# Customer Name      Claire Gute
# Segment               Consumer
# Age                         67
# Country          United States
# City                 Henderson
# State                 Kentucky
# Postal Code              42420
# Region                   South
# Name: CG-12520, dtype: object

# %%
df2.iloc[0]
# Out:
# Customer Name      Claire Gute
# Segment               Consumer
# Age                         67
# Country          United States
# City                 Henderson
# State                 Kentucky
# Postal Code              42420
# Region                   South
# Name: CG-12520, dtype: object

# %%
df3.loc["Los Angeles"]
# Out:
#             Customer ID        Customer Name      Segment  Age        Country  \
# City
# Los Angeles    DV-13045      Darrin Van Huff    Corporate   31  United States
# Los Angeles    BH-11710      Brosina Hoffman     Consumer   20  United States
# Los Angeles    EH-13945        Eric Hoffmann     Consumer   21  United States
# Los Angeles    RA-19885         Ruben Ausman    Corporate   51  United States
# Los Angeles    KM-16720         Kunst Miller     Consumer   69  United States
# Los Angeles    JS-15685             Jim Sink    Corporate   33  United States
# Los Angeles    LS-16975     Lindsay Shagiari  Home Office   66  United States
# Los Angeles    TT-21070          Ted Trevino     Consumer   67  United States
# Los Angeles    CS-12130         Chad Sievert     Consumer   51  United States
# Los Angeles    FM-14290         Frank Merwin  Home Office   45  United States
# Los Angeles    JH-15910      Jonathan Howell     Consumer   40  United States
# ...

# %%
df.iloc[0:4]
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
#
#               City       State  Postal Code Region
# 0        Henderson    Kentucky        42420  South
# 1      Los Angeles  California        90036   West
# 2  Fort Lauderdale     Florida        33311  South
# 3      Los Angeles  California        90032   West

# %%
df.iloc[0:4:2]
# Out:
#   Customer ID   Customer Name   Segment  Age        Country             City  \
# 0    CG-12520     Claire Gute  Consumer   67  United States        Henderson
# 2    SO-20335  Sean O'Donnell  Consumer   65  United States  Fort Lauderdale
#
#       State  Postal Code Region
# 0  Kentucky        42420  South
# 2   Florida        33311  South
